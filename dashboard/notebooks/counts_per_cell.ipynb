# %%
import numpy as np
import pandas as pd
import json

# %%
df = pd.read_csv('counts_per_cellclass.csv', index_col=0)
df
# Out:
#           Calb2_class  Cryab_class  Cxcl14_class  Gad1_class  Id2_class  \
# Bcl11b       0.131336     0.076019      0.101529    0.590606   0.204448
# Cadps2       0.036633     0.234672      1.101342    2.246538   1.322837
# Calb1        0.317931     0.005699      0.016279    0.001699   0.000000
# Calb2        4.583555     0.079184      0.014178    0.137380   0.182979
# Cck          0.000000     0.009854      0.017846    0.020291   0.000000
# ...               ...          ...           ...         ...        ...
# Thsd7a       0.277976     0.142373      0.715456    0.914187   0.997869
# Trp53i11     0.858052     0.161954      0.693340    0.559296   0.498094
# Vip          0.050962     0.002591      0.000000    0.040375   0.000230
# Wfs1         0.085971     0.246008      0.601451    0.617453   0.395401
# Yjefn3       0.000145     0.009253      0.000000    0.018230   0.084119
#
#           Lhx6_class  Pcp4_class  Pde1a_class  Plp1_class  Rgs4_class  \
# Bcl11b      0.297808    0.196209     0.555464    0.340205    0.218418
# Cadps2      1.025467    2.415688     0.527276    0.804243    0.294099
# Calb1       0.000000    0.000255     0.000000    0.000000    0.024495
# Calb2       2.325605    4.452097     0.137712    0.128495    0.019660
# Cck         0.000974    0.325221     0.065807    0.000000    0.027749
# ...              ...         ...          ...         ...         ...
# Thsd7a      0.404218    1.106418     0.423604    2.277477    0.123602
# Trp53i11    0.820200    0.941816     1.338703    0.854122    1.106247
# Vip         0.040067    0.000000     0.142551    0.674261    0.032970
# Wfs1        0.422202    0.100197     0.783038    3.826918    0.237899
# Yjefn3      0.129631    0.000000     0.071130    0.133638    0.085333
#
#           Satb1_class  Sncg_class      Zero
# Bcl11b       0.382719    0.175220  0.028337
# Cadps2       0.629690    0.521691  0.069794
# Calb1        0.023356    0.000000  0.002216
# Calb2        0.500319    0.102757  0.040185
# Cck          0.026613    0.000000  0.000211
# ...               ...         ...       ...
# Thsd7a       0.181591    0.208526  0.039015
# Trp53i11     0.589155    2.134595  0.036731
# Vip          0.000000    0.154242  0.000000
# Wfs1         0.250484    0.441383  0.074693
# Yjefn3       0.033136    0.157380  0.008468
#
# [70 rows x 13 columns]

# %%
df.columns.values
# Out:
# array(['Calb2_class', 'Cryab_class', 'Cxcl14_class', 'Gad1_class',
#        'Id2_class', 'Lhx6_class', 'Pcp4_class', 'Pde1a_class',
#        'Plp1_class', 'Rgs4_class', 'Satb1_class', 'Sncg_class', 'Zero'],
#       dtype=object)

# %%
# // {xKey: 1, xLabel: "Astro.1", yKey: 1, yLabel: "Astro.1", val: 0.1904853455312878}
_cols = df.columns.values
_rows = df.index.values

dictlist = []
arr = df.values
for r in range(arr.shape[0]):
    for c in range(arr.shape[1]):
        data = {}
        data['xKey'] = c+1
        data['xLabel'] = _cols[c]
        data['yKey'] = r+1
        data['yLabel'] = _rows[r]
        data['val'] = df.iloc[r, c]
        dictlist.append(data)

# %%
pd.DataFrame(dictlist).to_json('genes_by_class.json', orient='records')
